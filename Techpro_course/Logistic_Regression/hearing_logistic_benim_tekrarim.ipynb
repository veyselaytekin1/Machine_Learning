# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#%matplotlib notebook
plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df = pd.read_csv('hearing_test.csv')  
df.head()
# Out:
#      age  physical_score  test_result
# 0 33.000          40.700            1
# 1 50.000          37.200            1
# 2 52.000          24.700            0
# 3 56.000          31.000            0
# 4 35.000          42.900            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             5000 non-null   float64
#  1   physical_score  5000 non-null   float64
#  2   test_result     5000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 117.3 KB

# %%
df.isnull().sum()
# Out:
# age               0
# physical_score    0
# test_result       0
# dtype: int64

# %%
ax = sns.countplot(df['test_result'])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
for container in ax.containers:
    ax.bar_label(container);

# %%
sns.scatterplot(data=df,x='age', y= 'physical_score', hue='test_result')

#yaslari kücük olanlar testi gecme itimali
# Out:
# <AxesSubplot:xlabel='age', ylabel='physical_score'>

# %%
X = df.drop('test_result',axis=1)
y = df['test_result']

# %% [markdown]
# Train_test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y,test_size=0.1, random_state=101)

# %%
print("X Train features shape: {}\ny Train features shape: {}\nX Test features shape : {}\nY Test features shape : {}".format
      (X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X Train features shape: (4500, 2)
# y Train features shape: (4500,)
# X Test features shape : (500, 2)
# Y Test features shape : (500,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_scaled_train = scaler.fit_transform(X_train)
X_scaled_test = scaler.transform(X_test)
